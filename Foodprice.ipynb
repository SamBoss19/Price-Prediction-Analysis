# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_food = pd.read_csv("NAVGFood_Prices - NAVGFood_Prices.csv")
df_food.head()
# Out:
#         Date  Beans brown,sold loose  Beef,boneless  Frozen chicken  \
# 0  1/31/2017                  353.60        1249.48         1419.75
# 1  2/28/2017                  337.11        1270.67         1428.95
# 2  3/31/2017                  353.28        1281.71         1555.51
# 3  4/30/2017                  357.19        1323.10         1606.63
# 4  5/31/2017                  365.86        1378.91         1605.97
#
#    Gari white,sold loose  Rice,imported high quality sold loose  Titus:frozen  \
# 0                 219.56                                 402.01        884.82
# 1                 260.94                                 410.58        942.23
# 2                 273.67                                 418.71        964.63
# 3                 288.45                                 388.46        935.00
# 4                 292.97                                 410.55        969.64
#
#    Tomato  Yam tuber
# 0  247.55     210.58
# 1  236.62     215.55
# ...

# %%
df_food.describe()
# Out:
#        Beans brown,sold loose  Beef,boneless  Frozen chicken  \
# count               77.000000      77.000000       77.000000
# mean               412.751688    1546.490909     1958.302468
# std                 98.273726     393.215195      393.127363
# min                267.810000    1236.440000     1419.750000
# 25%                337.110000    1274.710000     1606.630000
# 50%                382.760000    1324.930000     1932.960000
# 75%                492.130000    1768.780000     2128.910000
# max                629.750000    2520.520000     2889.990000
#
#        Gari white,sold loose  Rice,imported high quality sold loose  \
# count              77.000000                              77.000000
# mean              250.912857                             491.181948
# std                67.309357                             126.493515
# min               145.310000                             352.830000
# 25%               195.860000                             373.040000
# ...

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date                                   77 non-null     object
#  1   Beans brown,sold loose                 77 non-null     float64
#  2   Beef,boneless                          77 non-null     float64
#  3   Frozen chicken                         77 non-null     float64
#  4   Gari white,sold loose                  77 non-null     float64
#  5   Rice,imported high quality sold loose  77 non-null     float64
#  6   Titus:frozen                           77 non-null     float64
#  7   Tomato                                 77 non-null     float64
#  8   Yam tuber                              77 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 5.5+ KB

# %%
df_food = df_food.set_index('Date')

# %%
df_food.head()
# Out:
#            Beans brown,sold loose  Beef,boneless  Frozen chicken  \
# Date
# 1/31/2017                  353.60        1249.48         1419.75
# 2/28/2017                  337.11        1270.67         1428.95
# 3/31/2017                  353.28        1281.71         1555.51
# 4/30/2017                  357.19        1323.10         1606.63
# 5/31/2017                  365.86        1378.91         1605.97
#
#            Gari white,sold loose  Rice,imported high quality sold loose  \
# Date
# 1/31/2017                 219.56                                 402.01
# 2/28/2017                 260.94                                 410.58
# 3/31/2017                 273.67                                 418.71
# 4/30/2017                 288.45                                 388.46
# 5/31/2017                 292.97                                 410.55
#
#            Titus:frozen  Tomato  Yam tuber
# Date
# 1/31/2017        884.82  247.55     210.58
# ...

# %%
df_food_C = df_food.copy()

# %%
df_food.columns
# Out:
# Index(['Beans brown,sold loose', 'Beef,boneless', 'Frozen chicken',
#        'Gari white,sold loose', 'Rice,imported high quality sold loose',
#        'Titus:frozen', 'Tomato', 'Yam tuber'],
#       dtype='object')

# %%
df_food= df_food.rename(columns = { 'Beans brown,sold loose' : 'Beans',
                                   'Beef,boneless' : 'Beef',
                                   'Frozen chicken' : 'Chicken',
                                    'Gari white,sold loose' : 'Garri',
                                    'Rice,imported high quality sold loose' : 'Rice', 
                                    'Titus:frozen': 'Titus'                            

} )

# %%
df_food.columns
# Out:
# Index(['Beans', 'Beef', 'Chicken', 'Garri', 'Rice', 'Titus', 'Tomato',
#        'Yam tuber'],
#       dtype='object')

# %%
plt.hist(df_food.Beans)
# Out:
# (array([ 8., 12., 15., 15.,  3.,  2.,  7.,  6.,  4.,  5.]),
#  array([267.81 , 304.004, 340.198, 376.392, 412.586, 448.78 , 484.974,
#         521.168, 557.362, 593.556, 629.75 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df_food.Beans)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x159a925d310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x159ab4c9610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x159a9308380>],
#  'medians': [<matplotlib.lines.Line2D at 0x159ab4c9bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x159ab4c9e80>],
#  'means': []}

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Beans, label='Beans Price')
plt.title('Beans Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Beans Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Tomato, label='Tomato Price')
plt.title('Tomato Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Tomato Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Beef, label='Beef Price')
plt.title('Beef Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Beef Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Chicken, label='Chicken Price')
plt.title('Chicken Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Chicken Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Titus, label='Titus Price')
plt.title('Titus Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Titus Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food['Yam tuber'], label='Yam tuber Price')
plt.title('Yam tuber Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Yam tuber Price')
plt.legend()
plt.show()

# %%
df_food.columns
# Out:
# Index(['Beans', 'Beef', 'Chicken', 'Garri', 'Rice', 'Titus', 'Tomato',
#        'Yam tuber'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Garri, label='Garri Price')
plt.title('Garri Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Garri Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_food.Rice, label='Rice Price')
plt.title('Rice Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Rice Price')
plt.legend()
plt.show()
